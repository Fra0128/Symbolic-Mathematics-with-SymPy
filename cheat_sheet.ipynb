# %%
from sympy import *

# %% [markdown]
# # Basics

# %% [markdown]
# ## Declare symbol

# %%
x = Symbol('x')
y = Symbol('y')
# or
x, y = symbols('x y')

# %% [markdown]
# ##  Substitution

# %%
expr = x/2 * (x + y**2 + 5 + 5*x)
expr.subs(x, 2)
# Out:
# y**2 + 17

# %% [markdown]
# ## Numerical evaluation

# %%
expr.evalf()
# Out:
# 0.5*x*(6.0*x + y**2 + 5.0)

# %% [markdown]
# ## Expanding

# %%
expr.expand()
# Out:
# 3*x**2 + x*y**2/2 + 5*x/2

# %% [markdown]
# ## Common denominator

# %%
ratsimp(expr)
# Out:
# 3*x**2 + x*y**2/2 + 5*x/2

# %% [markdown]
# ## Symplify expression

# %%
simplify(expr)
# Out:
# x*(6*x + y**2 + 5)/2

# %% [markdown]
# ## Sympy help

# %%
# help(expr)

# %% [markdown]
# # Costants

# %% [markdown]
# ## $\pi$

# %%
pi
# Out:
# pi

# %% [markdown]
# ## $e$

# %%
E
# Out:
# E

# %% [markdown]
# ## $\infty$

# %%
oo
# Out:
# oo

# %% [markdown]
# ## $i$

# %%
I
# Out:
# I

# %% [markdown]
# # Number types

# %% [markdown]
# ## Integers ($\mathbb{Z}$)

# %%
Integer(5.0)
# Out:
# 5

# %% [markdown]
# ## Ratonals ($\mathbb{Q}$)

# %%
Rational(5, 7)
# Out:
# 5/7

# %% [markdown]
# ## Reals ($\mathbb{R}$)

# %%
float(5)
# Out:
# 5.0

# %% [markdown]
# # Basic functions

# %% [markdown]
# ## Trigonometry

# %%
sin(pi/2)
# Out:
# 1

# %%
cos(pi)
# Out:
# -1

# %%
tan(pi/2) # tan(x) = sin(x)/cos(x)
# Out:
# zoo

# %%
cot(pi) # cot(x) = 1/tan(x)
# Out:
# zoo

# %% [markdown]
# ### Graphs

# %%
f1 = plotting.plot(sin(x), (x, 0, 2*pi), show=False, title='Sine')
f2 = plotting.plot(cos(x), (x, 0, 2*pi), show=False, title='Cosine')
f3 = plotting.plot(tan(x), (x, 0, 2*pi), show=False, title='Tangent')
f4 = plotting.plot(cot(x), (x, 0, 2*pi), show=False, title='Cotangent')

# plot the functions in a 1x4 grid
plotting.PlotGrid(4, 1, f1, f2, f3, f4, size=(3, 10))

# %% [markdown]
# ## Cyclometric

# %%
asin(1) # arcsin(x)= sin^-1(x)
# Out:
# pi/2

# %%
acos(0) # arccos(x)= cos^-1(x)
# Out:
# pi/2

# %%
atan(1) # arctan(x)= tan^-1(x)
# Out:
# pi/4

# %%
acot(1) # arccot(x)= cot^-1(x)
# Out:
# pi/4

# %% [markdown]
# ### Graphs

# %%
f1 = plotting.plot(asin(x), (x, 0, 2*pi), show=False, title='arcsin')
f2 = plotting.plot(acos(x), (x, 0, 2*pi), show=False, title='arccos')
f3 = plotting.plot(atan(x), (x, 0, 2*pi), show=False, title='arctan')
f4 = plotting.plot(acot(x), (x, 0, 2*pi), show=False, title='arccot')

# plot the functions in a 1x4 grid
plotting.PlotGrid(4, 1, f1, f2, f3, f4, size=(3, 10))

# %% [markdown]
# ## Hyperbolic

# %%
sinh(1) # sinh(x) = (e^x - e^(-x))/2
# Out:
# sinh(1)

# %%
cosh(1) # cosh(x) = (exp(x) + exp(-x))/2
# Out:
# cosh(1)

# %%
tanh(1) # tanh(x) = sinh(x)/cosh(x)
# Out:
# tanh(1)

# %%
coth(1) # coth(x) = 1/tanh(x)
# Out:
# coth(1)

# %% [markdown]
# ### Graphs

# %%
f1 = plotting.plot(sinh(x), (x, 0, 2*pi), show=False, title='hyperbolic sine')
f2 = plotting.plot(cosh(x), (x, 0, 2*pi), show=False, title='hyperbolic cosine')
f3 = plotting.plot(tanh(x), (x, 0, 2*pi), show=False, title='hyperbolic tangent')
f4 = plotting.plot(coth(x), (x, 0, 2*pi), show=False, title='hyperbolic cotangent')

# plot the functions in a 1x4 grid
plotting.PlotGrid(4, 1, f1, f2, f3, f4, size=(3, 10))
